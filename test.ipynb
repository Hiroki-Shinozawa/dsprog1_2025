# %%
import requests

# %%
url="https://www.musashino-u.ac.jp"
res=requests.get(url)

# %%
print(f"レス:{res}")
print(f"型:{type(res)}")
print(f"リクエスト:{res.request}")
# Out:
# レス:<Response [200]>
# 型:<class 'requests.models.Response'>
