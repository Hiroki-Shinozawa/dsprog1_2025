# %% [markdown]
# ## 課題：武蔵野大学 Web サイトのサイトマップ抽出
#
# - 目的：武蔵野大学のトップページ（https://www.musashino-u.ac.jp/）にアクセスし、同一ドメイン内の全リンクを辿って各ページの URL と <title> を収集し、辞書（key=URL、value=<title>）に格納して print() で表示する。
# - 実行上の制約：必ず time.sleep(seconds) を使ってサーバー負荷を軽減すること。
#
# GitHub フローの手順（ローカルでの操作例）：
#
# ```bash
# # 1. main (または upstream の最新) を取得
# git checkout main
# git pull origin main
#
# # 2. 新しい作業ブランチを作る
# git checkout -b feat/scrape-musashino-sitemap
#
# # 3. ノートブックを編集・保存（この assignment.ipynb を編集）
# # 4. 変更をステージしてコミット
# git add assignment.ipynb
# git commit -m "Add crawler notebook to extract musashino site titles"
#
# # 5. ブランチをリモートに push
# git push -u origin feat/scrape-musashino-sitemap
#
# # 6. GitHub で Pull Request を作成してレビュー・マージ
# ```
#
# 注意：ノートブックは差分が大きくなりがちです。必要に応じて出力を消してコミットするか、`.gitattributes` でノートブックの扱いを調整してください。

# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin, urlparse
# 武蔵野大学のトップページURL
start_url = "https://www.musashino-u.ac.jp/"
# サイトマップを格納する辞書 {URL: title}
sitemap = {}
# 訪問済みURLを記録
visited = set()
def scrape_page(url):
    """指定URLの<title>と内部リンクを抽出する関数"""
    try:
        # User-Agentを設定してブラウザからのアクセスに見せる
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        # ページにアクセス
        res = requests.get(url, headers=headers, timeout=10)
        res.encoding = res.apparent_encoding
        # ステータスコードのチェック
        if res.status_code != 200:
            print(f"スキップ: {url} (ステータスコード: {res.status_code})")
            return []
        # HTMLの解析
        soup = BeautifulSoup(res.text, "html.parser")
        # タイトルを取得
        title = soup.title.string.strip() if soup.title else "（タイトルなし）"
        sitemap[url] = title
        print(f"取得: {url} - {title}")
        # 内部リンクを収集
        links = []
        for a in soup.find_all("a", href=True):
            href = a["href"].strip()
            full_url = urljoin(url, href)
            # URLの正規化（末尾のスラッシュ処理など）
            parsed_url = urlparse(full_url)
            normalized_url = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}"
            if parsed_url.query:
                normalized_url += f"?{parsed_url.query}"
            # フラグメント（#以降）を削除
            normalized_url = normalized_url.split('#')[0]
            # 同一ドメインかつ不要な拡張子でないものを対象
            if urlparse(normalized_url).netloc == urlparse(start_url).netloc:
                if not normalized_url.lower().endswith((".pdf", ".jpg", ".jpeg", ".png", ".gif", ".mp4", ".zip", ".doc", ".docx", ".xls", ".xlsx", ".ppt", ".pptx")):
                    if normalized_url not in visited:
                        links.append(normalized_url)
        return links
    
    except Exception as e:
        print(f"エラー: {url} ({e})")
        return []
# クローリング開始
to_visit = [start_url]
max_pages = float('inf') # 取得ページ数の上限（必要に応じて調整）
count = 0
while to_visit and count < max_pages:
    # 次に訪問するURLを取得
    url = to_visit.pop(0)
    # 既に訪問済みならスキップ
    if url in visited:
        continue
    # URLを訪問済みに追加
    visited.add(url)
    count += 1
    # ページをスクレイプして新しいリンクを取得
    new_links = scrape_page(url)
    # サーバーに負荷をかけないよう待機
    time.sleep(1)
    # 新しく見つかったリンクを訪問キューに追加
    for link in new_links:
        if link not in visited and link not in to_visit:
            to_visit.append(link)
# 結果表示
print("\n=== スクレイピング結果 ===")
print(f"取得ページ数: {len(sitemap)}")
print("サイトマップ:")
print(sitemap)
# Out:
# 取得: https://www.musashino-u.ac.jp/ - 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/access.html - 交通アクセス | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/request.html - 資料請求 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/contact.html - お問い合わせ | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/prospective-students.html - 武蔵野大学で学びたい方 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/students.html - 在学生の方 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/alumni.html - 卒業生の方 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/parents.html - 保護者の方 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/business.html - 企業・研究者の方 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/ - 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/profile/ - 大学紹介 | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/activities/ - 大学の取り組み | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/campus/ - キャンパス | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/facility/ - 附置機関・センター・附属施設 | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/information/ - 情報公開 | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/profile/media/ - メディア | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/ - 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/ - 学部 入試情報 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/international_students/ - 留学生 入試情報 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/ - 大学院 入試情報 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/advanced_course/ - 専攻科 入試情報 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/short_term_course/ - 別科 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/event/ - 入試イベント | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faq/ - 入試Q＆A | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/download/ - 入学試験要項・出願書類 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/ - 教育の特長 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/purpose.html - 教育研究上の目的 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/policies/ - ３つの教育方針とアセスメント・ポリシー | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/learning_cycle.html - 響学スパイラル | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/initial/ - 武蔵野INITIAL | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/endowment_course.html - 寄付講座 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/consortium.html - 武蔵野地域５大学／放送大学単位互換 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/basic/generation_ai/index.html - 生成AIの活用に関する注意事項 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/ - 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/faculty/ - 学部 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/graduate_school/ - 大学院 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/advanced_course/ - 言語聴覚士養成課程（専攻科） | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/special_course/ - 別科 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/Lifelong_learning/ - 生涯学習・科目等履修制度 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/teachers_license/ - 教職課程・国家資格 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/ - 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/laboratory/ - 研究所・研究室・センター | 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/kakenhi/ - 科学研究費助成事業 | 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/cooperation/ - 産官学連携・研究推進センター紹介 | 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/ethics/ - 研究倫理教育 | 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/interview/ - 学問の地平から | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/alignment/collaborativeresearch.html - 連携研究の取り組み | 研究 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/ - 国際交流・留学 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/international-center/ - еӣҪйҡӣгӮ»гғігӮҝгғјгҒ«гҒӨгҒ„гҒҰ | еӣҪйҡӣдәӨжөҒгғ»з•ҷеӯҰ | жӯҰи”өйҮҺеӨ§еӯҰ
# 取得: https://www.musashino-u.ac.jp/international/study-abroad/ - 武蔵野大学から世界へ | 国際交流・留学 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/international-students/ - 武蔵野大学への留学 | 国際交流・留学 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/events/ - 国際交流イベント | 国際交流・留学 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/research_results/ - 受入教員研究成果 | 国際交流・留学 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/international/gc_portal/ - 全員留学ポータル | 全員留学ポータル | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/ - 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life
| 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/activities/privacypolicy.html - 個人情報保護方針 | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/accesibility-and-copyright.html - このサイトについて | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/ariake/index.html - 交通アクセス 有明キャンパス | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/campus/ariake_campus.html - 有明キャンパス | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/event/campus_tour.html - キャンパス見学（個人・団体）・Web入試相談 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/ariake/area_info.html - 宿泊施設 有明キャンパス | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/musashino/index.html - 交通アクセス 武蔵野キャンパス | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/guide/campus/musashino_campus.html - 武蔵野キャンパス | 大学案内 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/musashino/area_info.html - 宿泊施設 武蔵野キャンパス | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/satellite_mitaka.html - 三鷹サテライト教室 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/download/index.html - 入学試験要項・出願書類 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/download/international_students.html - 留学生入試 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/download/graduate_school.html - 大学院・専攻科入試 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/advanced_course/slht.html - 言語聴覚士養成課程（専攻科）入試 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/schedule.html - 入試日程 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/detail/ - 入試制度 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/detail/faculty.html - 学部から調べる | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/point/ - 入試のポイント | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/net.html - インターネット出願 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/examinee.html - 志願者速報 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/announcement.html - 合格発表 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/result.html - 入試結果 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/pastpapers.html - 過去問題　 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/correct_answer.html - 入学試験 解答　 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/hs_code.html - 高等学校等コード表 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/policies.html - アドミッション・ポリシー | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/event/weboc/ - 武蔵野大学 | Webオープンキャンパス
# 取得: https://www.musashino-u.ac.jp/admission/international_students/global_studies.html - 留学生入試 グローバル学部 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/international_students/other_studies.html - 留学生入試 グローバル学部以外 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/international_students/result.html - 入試結果 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/schedule01.html - 入試日程　修士課程 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/schedule02.html - 入試日程　博士後期課程 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/selection.html - 学内推薦 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/announcement.html - 合格発表 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/result.html - 入試結果 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/pastpapers.html - 過去問題 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/net.html - 大学院・専攻科　インターネット出願 | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/graduate_school/policies.html - アドミッション・ポリシー | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/event/event_calendar.html - 入試イベントカレンダー | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/event/graduate_counseling.html - 大学院・専攻科相談会  | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/event/teacher_advice_session.html - 高校教員の皆さま | 入試情報 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/career/qualification/qualification.html - 目指せる資格・免許一覧 | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/research/interview/index.html - 学問の地平から | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/fees/fees/ - 学費 | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/fees/scholarship/index.html - 奨学金 | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/academics/Lifelong_learning/credited_auditor/ - 科目等履修生制度 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/admission/faculty/event/weboc/pamphlet.html - 武蔵野大学 | Webオープンキャンパス | デジタルパンフレット
# 取得: https://www.musashino-u.ac.jp/academics/graduate_school/course/ - 大学院 | 学部・大学院 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/fees/fees/graduate_school.html - 学費（大学院） | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/link/muscat.html - 武蔵野大学 MUSCAT
# 取得: https://www.musashino-u.ac.jp/student-life/campus_life/calendar.html - 学年暦 | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/tool/information.html - 履修案内 | 学生生活・就職 | 武蔵野大学
# 取得: https://www.musashino-u.ac.jp/student-life/fees/index.html - 学費・奨学金 | 学生生活・就職 | 武蔵野大学
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 67
#      65 new_links = scrape_page(url)
#      66 # サーバーに負荷をかけないよう待機
# ---> 67 time.sleep(1)
#      68 # 新しく見つかったリンクを訪問キューに追加
#      69 for link in new_links:
#
# KeyboardInterrupt:
